# %%
#imports
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

#set ups
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
url = 'https://results.elections.europa.eu/en/turnout/'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="european-results" lang="en-GB" xml:lang="en-GB">
# <head prefix="
# 	og: http://ogp.me/ns#
# 	fb: http://ogp.me/ns/fb#
# 	article: http://ogp.me/ns/article#
# 	dc: http://purl.org/dc/elements/1.1/
# 	dcterms: http://purl.org/dc/terms/
# 	foaf: http://xmlns.com/foaf/0.1/
# 	schema: http://schema.org/
# 	xhv: http://www.w3.org/1999/xhtml/vocab
# 	rdf: http://www.w3.org/1999/02/22-rdf-syntax-ns#
# 	rdfa: http://www.w3.org/ns/rdfa#
# 	rdfs: http://www.w3.org/2000/01/rdf-schema#
# 	xsd: http://www.w3.org/2001/XMLSchema#
# 	">
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=yes" name="viewport">
# <title>Turnout | 2024 European election results | European Parliament</title>
# ...

# %%
#find all tables and store them in a variable named tables
table = soup.find_all('table',{"class":"turnout-by-country--table basic-table"})

# %%
for t in table: 
    heads = t.find_all('thead')
    for head in heads:
        columns = head.find_all('th')  # Find all 'th' elements within the 'thead'
        for column in columns:
            print(column.text)
# Out:
# Country
# 1979
# 1981
# 1984
# 1987
# 1989
# 1994
# 1995
# 1996
# 1999
# 2004
# 2007
# 2009
# 2013
# 2014
# 2019
# 2024

# %%
for t in table: 
    main_body = t.find_all('tbody')
    
    for body in main_body:
        cells = body.find_all('tr')  # Find all 'th' elements within the 'thead'
        print(cells)
       
#         for cell in cells:
#             text = cell.text.strip()
#             if not text:
#                 text = np.nan
        
#         print(text)  # Print the text or NaN
# Out:
# [<tr>
# <th class="turnout-by-country--data--name" scope="row">
# <span class="turnout-by-country--country-name--INTERACTIVE">Belgium</span>
# <span class="turnout-by-country--country-acronym--INTERACTIVE">BE</span>
# </th>
# <td class="turnout-by-country--data--year turnout-by-country--year-cell">91.36</td>
# <td class="turnout-by-country--data--year turnout-by-country--year-cell"></td>
# <td class="turnout-by-country--data--year turnout-by-country--year-cell">92.09</td>
# <td class="turnout-by-country--data--year turnout-by-country--year-cell"></td>
# <td class="turnout-by-country--data--year turnout-by-country--year-cell">90.73</td>
# <td class="turnout-by-country--data--year turnout-by-country--year-cell">90.66</td>
# <td class="turnout-by-country--data--year turnout-by-country--year-cell"></td>
# <td class="turnout-by-country--data--year turnout-by-country--year-cell"></td>
# <td class="turnout-by-country--data--year turnout-by-country--year-cell">91.05</td>
# ...

# %%
for t in table: 
    rows = t.find_all('tr')

    for row in rows:
        cells = row.find_all('td')
        for cell in cells:
            text = cell.text.strip()
            if not text:  # Check if the text is empty
                text = np.nan
            print(text)  # Print the text or NaN

# %%
header_texts = [header.text.strip() for header in headers]
header_texts

    
    #forw each row in rows
    for row in rows:
        
        #find all cell values
        cells = row.find_all('td')
        
        #define parties, leaders, seats, percentages and votes are found in your list of cell values 
        parties = cells[0::5]
        leaders = cells[1::5]
        seats = cells[2::5]
        percentages = cells[3::5]
        total_votes = cells[4::5]
        
        #Step 4: create an empty dictionary named mydata
        mydata = {}
        
        #We also have captions with useful info about parliamentary periods. Remember?
        #Grab the table caption and store it in a varialbe named caption
        caption = table.find('caption').text.strip()
        
        #create a dict key named caption and store your caption value there
        mydata['caption'] = caption
