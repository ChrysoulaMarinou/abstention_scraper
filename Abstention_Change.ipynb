# %%
import pandas as pd

# %%
df = pd.read_csv('df_absention_cleaned_14_06_2024__11_01.csv')

# %%
df.head()
# Out:
#    year  Belgium  Denmark  Germany  Ireland  France  Italy  Luxembourg  \
# 0  1979     8.64    52.18    34.27    36.39   39.29  14.35       11.09
# 1  1984     7.91    47.62    43.24    52.44   43.28  17.53       11.21
# 2  1989     9.27    53.83    37.72    31.72   51.20  18.93       12.61
# 3  1994     9.34    47.08    39.98    56.02   47.29  26.40       11.45
# 4  1999     8.95    49.54    54.81    49.79   53.24  30.24       12.73
#
#    Netherlands  United Kingdom  ...  Latvia  Hungary  Malta  Poland  Slovenia  \
# 0        41.88           67.65  ...     NaN      NaN    NaN     NaN       NaN
# 1        49.12           67.43  ...     NaN      NaN    NaN     NaN       NaN
# 2        52.52           63.63  ...     NaN      NaN    NaN     NaN       NaN
# 3        64.31           63.57  ...     NaN      NaN    NaN     NaN       NaN
# 4        69.98           76.00  ...     NaN      NaN    NaN     NaN       NaN
#
#    Slovakia  Bulgaria  Romania  Croatia  Total EU
# ...

# %%
df
# Out:
#    year  Belgium  Denmark  Germany  Ireland  France  Italy  Luxembourg  \
# 0  1979     8.64    52.18    34.27    36.39   39.29  14.35       11.09
# 1  1984     7.91    47.62    43.24    52.44   43.28  17.53       11.21
# 2  1989     9.27    53.83    37.72    31.72   51.20  18.93       12.61
# 3  1994     9.34    47.08    39.98    56.02   47.29  26.40       11.45
# 4  1999     8.95    49.54    54.81    49.79   53.24  30.24       12.73
# 5  2004     9.19    52.11    57.00    41.42   57.24  28.28        8.65
# 6  2009     9.61    40.46    56.73    41.36   59.37  33.53        9.24
# 7  2014    10.36    43.68    51.90    47.56   57.57  42.78       14.45
# 8  2019    11.53    33.92    38.62    50.30   49.88  45.50       15.76
# 9  2024    10.18    41.75    35.22    49.35   48.50  51.69       17.71
#
#    Netherlands  United Kingdom  ...  Latvia  Hungary  Malta  Poland  Slovenia  \
# 0        41.88           67.65  ...     NaN      NaN    NaN     NaN       NaN
# ...

# %%
df[(df.year==2024)].drop(['year', 'Total EU'], axis=1).T
# Out:
#                     9
# Belgium         10.18
# Denmark         41.75
# Germany         35.22
# Ireland         49.35
# France          48.50
# Italy           51.69
# Luxembourg      17.71
# Netherlands     53.80
# United Kingdom    NaN
# Greece          58.61
# Spain           50.79
# Portugal        63.46
# Sweden          46.60
# Austria         43.70
# Finland         59.60
# Czechia         63.55
# Estonia         62.40
# Cyprus          41.14
# Lithuania       71.65
# Latvia          66.18
# Hungary         40.55
# Malta           27.00
# Poland          59.35
# Slovenia        58.55
# Slovakia        65.62
# Bulgaria        66.21
# Romania         47.58
# Croatia         78.65

# %%
df[(df.year==2024)].drop(['year', 'Total EU'], axis=1).T.mean()
# Out:
# 9    51.088519
# dtype: float64

# %%
df[(df.year==2019)].drop(['year', 'Total EU'], axis=1).T.mean()
# Out:
# 8    51.249286
# dtype: float64

# %%
df['Greece']
# Out:
# 0      NaN
# 1    19.41
# 2    19.97
# 3    26.82
# 4    29.75
# 5    36.78
# 6    47.46
# 7    40.03
# 8    41.31
# 9    58.61
# Name: Greece, dtype: float64

# %%
# test = df[['year','Greece']]
# test

# %%
df1 = df.diff(periods = 1)
df1 = df1.drop('year', axis=1)

df1
# Out:
#    Belgium  Denmark  Germany  Ireland  France  Italy  Luxembourg  Netherlands  \
# 0      NaN      NaN      NaN      NaN     NaN    NaN         NaN          NaN
# 1    -0.73    -4.56     8.97    16.05    3.99   3.18        0.12         7.24
# 2     1.36     6.21    -5.52   -20.72    7.92   1.40        1.40         3.40
# 3     0.07    -6.75     2.26    24.30   -3.91   7.47       -1.16        11.79
# 4    -0.39     2.46    14.83    -6.23    5.95   3.84        1.28         5.67
# 5     0.24     2.57     2.19    -8.37    4.00  -1.96       -4.08        -9.24
# 6     0.42   -11.65    -0.27    -0.06    2.13   5.25        0.59         2.51
# 7     0.75     3.22    -4.83     6.20   -1.80   9.25        5.21        -0.57
# 8     1.17    -9.76   -13.28     2.74   -7.69   2.72        1.31        -4.61
# 9    -1.35     7.83    -3.40    -0.95   -1.38   6.19        1.95        -4.27
#
#    United Kingdom  Greece  ...  Latvia  Hungary  Malta  Poland  Slovenia  \
# ...

# %%
df_year = pd.DataFrame(df['year'])
df_year
# Out:
#    year
# 0  1979
# 1  1984
# 2  1989
# 3  1994
# 4  1999
# 5  2004
# 6  2009
# 7  2014
# 8  2019
# 9  2024

# %%
df_final = pd.concat([df_year, df1], axis = 1)
df_final
# Out:
#    year  Belgium  Denmark  Germany  Ireland  France  Italy  Luxembourg  \
# 0  1979      NaN      NaN      NaN      NaN     NaN    NaN         NaN
# 1  1984    -0.73    -4.56     8.97    16.05    3.99   3.18        0.12
# 2  1989     1.36     6.21    -5.52   -20.72    7.92   1.40        1.40
# 3  1994     0.07    -6.75     2.26    24.30   -3.91   7.47       -1.16
# 4  1999    -0.39     2.46    14.83    -6.23    5.95   3.84        1.28
# 5  2004     0.24     2.57     2.19    -8.37    4.00  -1.96       -4.08
# 6  2009     0.42   -11.65    -0.27    -0.06    2.13   5.25        0.59
# 7  2014     0.75     3.22    -4.83     6.20   -1.80   9.25        5.21
# 8  2019     1.17    -9.76   -13.28     2.74   -7.69   2.72        1.31
# 9  2024    -1.35     7.83    -3.40    -0.95   -1.38   6.19        1.95
#
#    Netherlands  United Kingdom  ...  Latvia  Hungary  Malta  Poland  Slovenia  \
# 0          NaN             NaN  ...     NaN      NaN    NaN     NaN       NaN
# ...

# %%
df_final = df_final.T.reset_index()
df_final
# Out:
#              index       0        1        2        3        4        5  \
# 0             year  1979.0  1984.00  1989.00  1994.00  1999.00  2004.00
# 1          Belgium     NaN    -0.73     1.36     0.07    -0.39     0.24
# 2          Denmark     NaN    -4.56     6.21    -6.75     2.46     2.57
# 3          Germany     NaN     8.97    -5.52     2.26    14.83     2.19
# 4          Ireland     NaN    16.05   -20.72    24.30    -6.23    -8.37
# 5           France     NaN     3.99     7.92    -3.91     5.95     4.00
# 6            Italy     NaN     3.18     1.40     7.47     3.84    -1.96
# 7       Luxembourg     NaN     0.12     1.40    -1.16     1.28    -4.08
# 8      Netherlands     NaN     7.24     3.40    11.79     5.67    -9.24
# 9   United Kingdom     NaN    -0.22    -3.80    -0.06    12.43   -14.52
# 10          Greece     NaN      NaN     0.56     6.85     2.93     7.03
# 11           Spain     NaN      NaN      NaN    -4.43    -3.91    17.91
# ...

# %%
df_final.columns = df_final.iloc[0]
df_final = df_final[1:]
df_final
# Out:
# 0             year  1979.0  1984.0  1989.0  1994.0  1999.0  2004.0  2009.0  \
# 1          Belgium     NaN   -0.73    1.36    0.07   -0.39    0.24    0.42
# 2          Denmark     NaN   -4.56    6.21   -6.75    2.46    2.57  -11.65
# 3          Germany     NaN    8.97   -5.52    2.26   14.83    2.19   -0.27
# 4          Ireland     NaN   16.05  -20.72   24.30   -6.23   -8.37   -0.06
# 5           France     NaN    3.99    7.92   -3.91    5.95    4.00    2.13
# 6            Italy     NaN    3.18    1.40    7.47    3.84   -1.96    5.25
# 7       Luxembourg     NaN    0.12    1.40   -1.16    1.28   -4.08    0.59
# 8      Netherlands     NaN    7.24    3.40   11.79    5.67   -9.24    2.51
# 9   United Kingdom     NaN   -0.22   -3.80   -0.06   12.43  -14.52    3.82
# 10          Greece     NaN     NaN    0.56    6.85    2.93    7.03   10.68
# 11           Spain     NaN     NaN     NaN   -4.43   -3.91   17.91    0.27
# ...

# %%
df_final = df_final.sort_values(by=2024.0,ascending=False)
df_final
# Out:
# 0             year  1979.0  1984.0  1989.0  1994.0  1999.0  2004.0  2009.0  \
# 19       Lithuania     NaN     NaN     NaN     NaN     NaN     NaN   27.40
# 10          Greece     NaN     NaN    0.56    6.85    2.93    7.03   10.68
# 11           Spain     NaN     NaN     NaN   -4.43   -3.91   17.91    0.27
# 28         Croatia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2          Denmark     NaN   -4.56    6.21   -6.75    2.46    2.57  -11.65
# 6            Italy     NaN    3.18    1.40    7.47    3.84   -1.96    5.25
# 23          Poland     NaN     NaN     NaN     NaN     NaN     NaN   -3.66
# 14         Austria     NaN     NaN     NaN     NaN     NaN    6.97   -3.54
# 7       Luxembourg     NaN    0.12    1.40   -1.16    1.28   -4.08    0.59
# 13          Sweden     NaN     NaN     NaN     NaN     NaN    0.99   -7.68
# 15         Finland     NaN     NaN     NaN     NaN     NaN   -9.29    0.83
# ...

# %%
top = df_final.head(11)
top = top[['year',2024.0]]
top = top.rename(columns = {'year':'country',
                           2024.0:'change'})
top
# Out:
# 0      country  change
# 19   Lithuania   25.13
# 10      Greece   17.30
# 11       Spain   11.52
# 28     Croatia    8.50
# 2      Denmark    7.83
# 6        Italy    6.19
# 23      Poland    5.03
# 14     Austria    3.50
# 7   Luxembourg    1.95
# 13      Sweden    1.87
# 15     Finland    0.40

# %%
top.to_csv('change.csv', index=False)

# %%
df
# Out:
#    year  Belgium  Denmark  Germany  Ireland  France  Italy  Luxembourg  \
# 0  1979     8.64    52.18    34.27    36.39   39.29  14.35       11.09
# 1  1984     7.91    47.62    43.24    52.44   43.28  17.53       11.21
# 2  1989     9.27    53.83    37.72    31.72   51.20  18.93       12.61
# 3  1994     9.34    47.08    39.98    56.02   47.29  26.40       11.45
# 4  1999     8.95    49.54    54.81    49.79   53.24  30.24       12.73
# 5  2004     9.19    52.11    57.00    41.42   57.24  28.28        8.65
# 6  2009     9.61    40.46    56.73    41.36   59.37  33.53        9.24
# 7  2014    10.36    43.68    51.90    47.56   57.57  42.78       14.45
# 8  2019    11.53    33.92    38.62    50.30   49.88  45.50       15.76
# 9  2024    10.18    41.75    35.22    49.35   48.50  51.69       17.71
#
#    Netherlands  United Kingdom  ...  Latvia  Hungary  Malta  Poland  Slovenia  \
# 0        41.88           67.65  ...     NaN      NaN    NaN     NaN       NaN
# ...
